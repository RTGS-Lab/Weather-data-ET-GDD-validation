# %%
#Import required libraries
import pandas as pd
import numpy as np
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error

# %%
# Load the CSV file from GEMS exchange
df_GEMS_Becker2022 = pd.read_csv('Gemsexchage_data/gems_weather_export_Becker_2022-01-01_to_2022-12-31_units(M).csv')
df_GEMS_Clarissa2022 = pd.read_csv('Gemsexchage_data/gems_weather_export_Clarissa_2022-01-01_to_2022-12-31_units(M).csv')
df_GEMS_Clarissa2022 = pd.read_csv('Gemsexchage_data/gems_weather_export_Clarissa_2022-01-01_to_2022-12-31_units(M).csv')
df_GEMS_Dakota2022 = pd.read_csv('Gemsexchage_data/gems_weather_export_dakota_2022-01-01_to_2022-12-31_units(M).csv')
df_GEMS_Douglas2022 = pd.read_csv('Gemsexchage_data/gems_weather_export_douglas_2022-01-01_to_2022-12-31_units(M).csv')
df_GEMS_Hubbard2022 = pd.read_csv('Gemsexchage_data/gems_weather_export_Hubbard_2022-01-01_to_2022-12-31_units(M).csv')
df_GEMS_LittleFalls2022 = pd.read_csv('Gemsexchage_data/gems_weather_export_LittleFalls_2022-01-01_to_2022-12-31_units(M).csv')
df_GEMS_OtterTail2022 = pd.read_csv('Gemsexchage_data/gems_weather_export_OtterTail_2022-01-01_to_2022-12-31_units(M).csv')
df_GEMS_ParkersPrairie2022 = pd.read_csv('Gemsexchage_data/gems_weather_export_ParkersPrairie_2022-01-01_to_2022-12-31_units(M).csv')
df_GEMS_Perham2022 = pd.read_csv('Gemsexchage_data/gems_weather_export_Perham_2022-01-01_to_2022-12-31_units(M).csv')
df_GEMS_PinePoint2022 = pd.read_csv('Gemsexchage_data/gems_weather_export_PinePoint_2022-01-01_to_2022-12-31_units(M).csv')
df_GEMS_Rice2022 = pd.read_csv('Gemsexchage_data/gems_weather_export_Rice_2022-01-01_to_2022-12-31_units(M).csv')
df_GEMS_Staples2022 = pd.read_csv('Gemsexchage_data/gems_weather_export_Staples_2022-01-01_to_2022-12-31_units(M).csv')
df_GEMS_Wadena2022 = pd.read_csv('Gemsexchage_data/gems_weather_export_Wadena_2022-01-01_to_2022-12-31_units(M).csv')
df_GEMS_Westport2022 = pd.read_csv('Gemsexchage_data/gems_weather_export_Westport_2022-01-01_to_2022-12-31_units(M).csv')
df_GEMS_Becker2023 = pd.read_csv('Gemsexchage_data/gems_weather_export_Becker_2023-01-01_to_2023-12-31_units(M).csv')
df_GEMS_Clarissa2023 = pd.read_csv('Gemsexchage_data/gems_weather_export_Clarissa_2023-01-01_to_2023-12-31_units(M).csv')
df_GEMS_Dakota2023 = pd.read_csv('Gemsexchage_data/gems_weather_export_dakota_2023-01-01_to_2023-12-31_units(M).csv')
df_GEMS_Douglas2023 = pd.read_csv('Gemsexchage_data/gems_weather_export_douglas_2023-01-01_to_2023-12-31_units(M).csv')
df_GEMS_Hubbard2023 = pd.read_csv('Gemsexchage_data/gems_weather_export_Hubbard_2023-01-01_to_2023-12-31_units(M).csv')
df_GEMS_LittleFalls2023 = pd.read_csv('Gemsexchage_data/gems_weather_export_LittleFalls_2023-01-01_to_2023-12-31_units(M).csv')
df_GEMS_OtterTail2023 = pd.read_csv('Gemsexchage_data/gems_weather_export_OtterTail_2023-01-01_to_2023-12-31_units(M).csv')
df_GEMS_ParkersPrairie2023 = pd.read_csv('Gemsexchage_data/gems_weather_export_ParkersPrairie_2023-01-01_to_2023-12-31_units(M).csv')
df_GEMS_Perham2023 = pd.read_csv('Gemsexchage_data/gems_weather_export_Perham_2023-01-01_to_2023-12-31_units(M).csv')
df_GEMS_PinePoint2023 = pd.read_csv('Gemsexchage_data/gems_weather_export_PinePoint_2023-01-01_to_2023-12-31_units(M).csv')
df_GEMS_Rice2023 = pd.read_csv('Gemsexchage_data/gems_weather_export_Rice_2023-01-01_to_2023-12-31_units(M).csv')
df_GEMS_Staples2023 = pd.read_csv('Gemsexchage_data/gems_weather_export_Staples_2023-01-01_to_2023-12-31_units(M).csv')
df_GEMS_Wadena2023 = pd.read_csv('Gemsexchage_data/gems_weather_export_Wadena_2023-01-01_to_2023-12-31_units(M).csv')
df_GEMS_Westport2023 = pd.read_csv('Gemsexchage_data/gems_weather_export_Westport_2023-01-01_to_2023-12-31_units(M).csv')

# %%
#Load clean CSV file from MDA
df_BeckerMDA_2022 = pd.read_csv('MDAclean_data/Becker_clean_MDA_2022.csv')
df_BeckerMDA_2023 = pd.read_csv('MDAclean_data/Becker_clean_MDA_2023.csv')
df_ClarissaMDA_2022 = pd.read_csv('MDAclean_data/Clarissa_clean_MDA_2022.csv')
df_ClarissaMDA_2023 = pd.read_csv('MDAclean_data/Clarissa_clean_MDA_2023.csv')
df_HastingsMDA_2022 = pd.read_csv('MDAclean_data/Hastings_clean_MDA_2022.csv')
df_HastingsMDA_2023 = pd.read_csv('MDAclean_data/Hastings_clean_MDA_2023.csv')
df_HubbardMDA_2022 = pd.read_csv('MDAclean_data/Hubbard_clean_MDA_2022.csv')
df_HubbardMDA_2023 = pd.read_csv('MDAclean_data/Hubbard_clean_MDA_2023.csv')
df_LittleFallsMDA_2022 = pd.read_csv('MDAclean_data/LittleFalls_clean_MDA_2022.csv')
df_LittleFallsMDA_2023 = pd.read_csv('MDAclean_data/LittleFalls_clean_MDA_2023.csv')
df_OtterTailMDA_2022 = pd.read_csv('MDAclean_data/Ottertail_clean_MDA_2022.csv')
df_OtterTailMDA_2023 = pd.read_csv('MDAclean_data/Ottertail_clean_MDA_2023.csv')
df_ParkersPrairieMDA_2022 = pd.read_csv('MDAclean_data/ParkersPrairie_clean_MDA_2022.csv')
df_ParkersPrairieMDA_2023 = pd.read_csv('MDAclean_data/ParkersPrairie_clean_MDA_2023.csv')
df_PerhamMDA_2022 = pd.read_csv('MDAclean_data/Perham_clean_MDA_2022.csv')
df_PerhamMDA_2023 = pd.read_csv('MDAclean_data/Perham_clean_MDA_2023.csv')
df_PinePointMDA_2022 = pd.read_csv('MDAclean_data/PinePoint_clean_MDA_2022.csv')
df_PinePointMDA_2023 = pd.read_csv('MDAclean_data/PinePoint_clean_MDA_2023.csv')
df_RiceMDA_2022 = pd.read_csv('MDAclean_data/Rice_clean_MDA_2022.csv')
df_RiceMDA_2023 = pd.read_csv('MDAclean_data/Rice_Clean_MDA_2023.csv')
df_StaplesMDA_2022 = pd.read_csv('MDAclean_data/Staples_clean_MDA_2022.csv')
df_StaplesMDA_2023 = pd.read_csv('MDAclean_data/Staples_clean_MDA_2023.csv')
df_WadenaMDA_2022 = pd.read_csv('MDAclean_data/Wadena_clean_MDA_2022.csv')
df_WadenaMDA_2023 = pd.read_csv('MDAclean_data/Wadena_clean_MDA_2023.csv')
df_WestportMDA_2022 = pd.read_csv('MDAclean_data/Westport_clean_MDA_2022.csv')
df_WestportMDA_2023 = pd.read_csv('MDAclean_data/Westport_clean_MDA_2023.csv')

# %%
#GDD calculation for corn from class CornGDD. 
import pandas as pd

def fahrenheit_to_celsius(temp_f):
    return (temp_f - 32) * 5 / 9

def celsius_to_fahrenheit(temp_c):
    return (temp_c * 9 / 5) + 32

class CornGDD:
    def __init__(self, daily_temp_df, time_column, min_temp_column, max_temp_column, celsius=True):
        self.daily_temp_df = daily_temp_df
        self.time_column = time_column
        self.min_temp_column = min_temp_column
        self.max_temp_column = max_temp_column
        self.celsius = celsius

        # Ensure the time column is of datetime type
        self.daily_temp_df[self.time_column] = pd.to_datetime(self.daily_temp_df[self.time_column])

        # If initial data is in Celsius, optionally convert it to Fahrenheit for uniform GDD calculation
        if self.celsius:
            self.daily_temp_df[self.min_temp_column] = self.daily_temp_df[self.min_temp_column].apply(celsius_to_fahrenheit)
            self.daily_temp_df[self.max_temp_column] = self.daily_temp_df[self.max_temp_column].apply(celsius_to_fahrenheit)
            self.celsius = False  # Now all data is in Fahrenheit

    def con_gdd(self, start_date, end_date):
        start_date = pd.Timestamp(start_date)
        end_date = pd.Timestamp(end_date)

        date_mask = (self.daily_temp_df[self.time_column] >= start_date) & (self.daily_temp_df[self.time_column] <= end_date)
        masked_data = self.daily_temp_df.loc[date_mask].copy()

        gdd_values = []
        cumulative_gdd = 0

        for index, row in masked_data.iterrows():
            min_temp = max(row[self.min_temp_column], 50)  # Fahrenheit base
            max_temp = min(row[self.max_temp_column], 86)  # Fahrenheit upper limit

            mean_temp = (min_temp + max_temp) / 2
            base_temp = 50  # Fahrenheit base temperature for GDD calculation
            gdd = max(mean_temp - base_temp, 0)

            gdd_values.append(gdd)
            cumulative_gdd += gdd

        masked_data['GDD'] = gdd_values
        masked_data['Cumulative_GDD'] = masked_data['GDD'].cumsum()

        return masked_data

# This modified class converts temperatures to Fahrenheit if they start in Celsius, then computes and returns GDD in Fahrenheit.

# %%
#Input data using CornGDD instance for all 16 weather stations
corn_GEMS_Becker2022 = CornGDD(df_GEMS_Becker2022, time_column = 'Date', min_temp_column = ('min_temp'), max_temp_column = 'max_temp')
corn_GEMS_Clarissa2022 = CornGDD(df_GEMS_Clarissa2022, time_column = 'Date', min_temp_column = 'min_temp', max_temp_column = 'max_temp')
corn_GEMS_Hastings2022 = CornGDD(df_GEMS_Dakota2022, time_column = 'Date', min_temp_column = 'min_temp', max_temp_column = 'max_temp')
corn_GEMS_Hubbard2022 = CornGDD(df_GEMS_Hubbard2022, time_column = 'Date', min_temp_column = 'min_temp', max_temp_column = 'max_temp')
corn_GEMS_LittleFalls2022 = CornGDD(df_GEMS_LittleFalls2022,time_column = 'Date', min_temp_column = 'min_temp', max_temp_column = 'max_temp')
corn_GEMS_OtterTail2022 = CornGDD(df_GEMS_OtterTail2022, time_column = 'Date', min_temp_column = 'min_temp', max_temp_column = 'max_temp')
corn_GEMS_ParkersPrairie2022 = CornGDD(df_GEMS_ParkersPrairie2022, time_column = 'Date', min_temp_column = 'min_temp', max_temp_column = 'max_temp')
corn_GEMS_Perham2022 = CornGDD(df_GEMS_Perham2022, time_column = 'Date', min_temp_column = 'min_temp', max_temp_column = 'max_temp')
corn_GEMS_PinePoint2022 = CornGDD(df_GEMS_PinePoint2022, time_column = 'Date', min_temp_column = 'min_temp', max_temp_column = 'max_temp')
corn_GEMS_Rice2022 = CornGDD(df_GEMS_Rice2022, time_column = 'Date', min_temp_column = 'min_temp', max_temp_column = 'max_temp')
corn_GEMS_Staples2022 = CornGDD(df_GEMS_Staples2022, time_column = 'Date', min_temp_column = 'min_temp', max_temp_column = 'max_temp')
corn_GEMS_Wadena2022 = CornGDD(df_GEMS_Wadena2022, time_column = 'Date', min_temp_column = 'min_temp', max_temp_column = 'max_temp')
corn_GEMS_Westport2022 = CornGDD(df_GEMS_Westport2022, time_column = 'Date', min_temp_column = 'min_temp', max_temp_column = 'max_temp')

# %%
# Input data using CornGDD instance for all 16 weather stations for the year 2023
corn_GEMS_Becker2023 = CornGDD(df_GEMS_Becker2023, time_column='Date', min_temp_column='min_temp', max_temp_column='max_temp')
corn_GEMS_Clarissa2023 = CornGDD(df_GEMS_Clarissa2023, time_column='Date', min_temp_column='min_temp', max_temp_column='max_temp')
corn_GEMS_Hastings2023 = CornGDD(df_GEMS_Dakota2023, time_column='Date', min_temp_column='min_temp', max_temp_column='max_temp')
corn_GEMS_Hubbard2023 = CornGDD(df_GEMS_Hubbard2023, time_column='Date', min_temp_column='min_temp', max_temp_column='max_temp')
corn_GEMS_LittleFalls2023 = CornGDD(df_GEMS_LittleFalls2023, time_column='Date', min_temp_column='min_temp', max_temp_column='max_temp')
corn_GEMS_OtterTail2023 = CornGDD(df_GEMS_OtterTail2023, time_column='Date', min_temp_column='min_temp', max_temp_column='max_temp')
corn_GEMS_ParkersPrairie2023 = CornGDD(df_GEMS_ParkersPrairie2023, time_column='Date', min_temp_column='min_temp', max_temp_column='max_temp')
corn_GEMS_Perham2023 = CornGDD(df_GEMS_Perham2023, time_column='Date', min_temp_column='min_temp', max_temp_column='max_temp')
corn_GEMS_PinePoint2023 = CornGDD(df_GEMS_PinePoint2023, time_column='Date', min_temp_column='min_temp', max_temp_column='max_temp')
corn_GEMS_Rice2023 = CornGDD(df_GEMS_Rice2023, time_column='Date', min_temp_column='min_temp', max_temp_column='max_temp')
corn_GEMS_Staples2023 = CornGDD(df_GEMS_Staples2023, time_column='Date', min_temp_column='min_temp', max_temp_column='max_temp')
corn_GEMS_Wadena2023 = CornGDD(df_GEMS_Wadena2023, time_column='Date', min_temp_column='min_temp', max_temp_column='max_temp')
corn_GEMS_Westport2023 = CornGDD(df_GEMS_Westport2023, time_column='Date', min_temp_column='min_temp', max_temp_column='max_temp')

# %%
#Input start date and End date for the data for year 2022
start_date = pd.to_datetime("2022-01-01").date()
end_date = pd.to_datetime("2022-12-30").date()

# %%
#Input start and end date for the data for year 2023
start_date = pd.to_datetime("2023-01-01").date()
end_date = pd.to_datetime("2023-12-30").date()

# %%
#using con_gdd from class CornGDD getting GDD values
corn_GEMS_Becker2022_gdd = corn_GEMS_Becker2022.con_gdd(start_date, end_date)
corn_GEMS_Clarissa2022_gdd = corn_GEMS_Clarissa2022.con_gdd(start_date, end_date)
corn_GEMS_Hastings2022_gdd = corn_GEMS_Hastings2022.con_gdd(start_date, end_date)
corn_GEMS_Hubbard2022_gdd = corn_GEMS_Hubbard2022.con_gdd(start_date, end_date)
corn_GEMS_LittleFalls2022_gdd =corn_GEMS_LittleFalls2022.con_gdd(start_date, end_date) 
corn_GEMS_OtterTail2022_gdd = corn_GEMS_OtterTail2022.con_gdd(start_date, end_date)
corn_GEMS_ParkersPrairie2022_gdd = corn_GEMS_ParkersPrairie2022.con_gdd(start_date, end_date)
corn_GEMS_Perham2022_gdd =  corn_GEMS_Perham2022.con_gdd(start_date, end_date)
corn_GEMS_PinePoint2022_gdd = corn_GEMS_PinePoint2022.con_gdd(start_date, end_date)
corn_GEMS_Rice2022_gdd = corn_GEMS_Rice2022.con_gdd(start_date, end_date)
corn_GEMS_Staples2022_gdd = corn_GEMS_Staples2022.con_gdd(start_date, end_date)
corn_GEMS_Wadena2022_gdd = corn_GEMS_Wadena2022.con_gdd(start_date, end_date)
corn_GEMS_Westport2022_gdd = corn_GEMS_Westport2022.con_gdd(start_date, end_date)

# %%
# Using con_gdd from class CornGDD to get GDD values for 2023
corn_GEMS_Becker2023_gdd = corn_GEMS_Becker2023.con_gdd(start_date, end_date)
corn_GEMS_Clarissa2023_gdd = corn_GEMS_Clarissa2023.con_gdd(start_date, end_date)
corn_GEMS_Hastings2023_gdd = corn_GEMS_Hastings2023.con_gdd(start_date, end_date)
corn_GEMS_Hubbard2023_gdd = corn_GEMS_Hubbard2023.con_gdd(start_date, end_date)
corn_GEMS_LittleFalls2023_gdd = corn_GEMS_LittleFalls2023.con_gdd(start_date, end_date)
corn_GEMS_OtterTail2023_gdd = corn_GEMS_OtterTail2023.con_gdd(start_date, end_date)
corn_GEMS_ParkersPrairie2023_gdd = corn_GEMS_ParkersPrairie2023.con_gdd(start_date, end_date)
corn_GEMS_Perham2023_gdd = corn_GEMS_Perham2023.con_gdd(start_date, end_date)
corn_GEMS_PinePoint2023_gdd = corn_GEMS_PinePoint2023.con_gdd(start_date, end_date)
corn_GEMS_Rice2023_gdd = corn_GEMS_Rice2023.con_gdd(start_date, end_date)
corn_GEMS_Staples2023_gdd = corn_GEMS_Staples2023.con_gdd(start_date, end_date)
corn_GEMS_Wadena2023_gdd = corn_GEMS_Wadena2023.con_gdd(start_date, end_date)
corn_GEMS_Westport2023_gdd = corn_GEMS_Westport2023.con_gdd(start_date, end_date)

# %%
#Regression analysis for MDA 2022 data and GEMS exchange 2022 data
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error
from scipy.stats import pearsonr 
# Define the locations and corresponding dataframes
locations = [
    ("Becker22", df_BeckerMDA_2022, corn_GEMS_Becker2022_gdd),
    ("Clarissa22", df_ClarissaMDA_2022,corn_GEMS_Clarissa2022_gdd),
    ("Hubbard22", df_HubbardMDA_2022, corn_GEMS_Hubbard2022_gdd),
    ("Dakota22", df_HastingsMDA_2022, corn_GEMS_Hastings2022_gdd),
    ("LittleFalls22", df_LittleFallsMDA_2022, corn_GEMS_LittleFalls2022_gdd),
    ("Ottertail22", df_OtterTailMDA_2022, corn_GEMS_OtterTail2022_gdd),
    ("ParkersPrairie22", df_ParkersPrairieMDA_2022, corn_GEMS_ParkersPrairie2022_gdd),
    ("Perham22", df_PerhamMDA_2022, corn_GEMS_Perham2022_gdd),
    ("PinePoint22", df_PinePointMDA_2022, corn_GEMS_PinePoint2022_gdd),
    ("Rice22", df_RiceMDA_2022, corn_GEMS_Rice2022_gdd),
    ("Staples22", df_StaplesMDA_2022, corn_GEMS_Staples2022_gdd),
    ("Wadena22", df_WadenaMDA_2022, corn_GEMS_Wadena2022_gdd),
    ("Westport22", df_WestportMDA_2022, corn_GEMS_Westport2022_gdd)
]

# Combine all data for regression analysis
all_data = pd.DataFrame()

for location_name, df_MDA, df_GEMS in locations:
    combined = pd.DataFrame({
        'MDA': df_MDA['CornGDD_daily'], 
        'GEMS': df_GEMS['GDD']
    })
    all_data = pd.concat([all_data, combined])

# Drop any rows with NaN values to ensure consistent lengths
all_data.dropna(inplace=True)

# Extract X and y for regression
X = all_data['MDA'].values.reshape(-1, 1)
y = all_data['GEMS'].values

# Linear regression
model = LinearRegression()
model.fit(X, y)
predictions = model.predict(X)

# Calculate overall metrics
r2 = r2_score(y, predictions)
rmse = np.sqrt(mean_squared_error(y, predictions))
mae = mean_absolute_error(y, predictions)

# Plot
plt.figure(figsize=(10, 6))
plt.scatter(X, y, color='gray', label='Data points')
plt.plot(X, predictions, color='red', label='Regression Line')
plt.plot(X, X, linestyle='--', color='black', label='1:1 Line')  # 1:1 Line
plt.title('Combined Regression Analysis for All Locations for 2022')
plt.xlabel('MDA GDD')
plt.ylabel('GEMS GDD')

plt.legend(loc='upper left')  # Move the legend to top left

# Display R2, RMSE, and MAE
textstr = f'R-squared: {r2:.5f}\nRMSE: {rmse:.5f}°f\nMAE: {mae:.5f}°f'
plt.text(0.95, 0.05, textstr, transform=plt.gca().transAxes, fontsize=12,
          verticalalignment='bottom', horizontalalignment='right')

plt.tight_layout()
plt.show()
# Calculate Pearson correlation coefficient and p-value
#pearson_corr, p_value = pearsonr(X.flatten(), y)
# Print Pearson correlation coefficient and p-value
#print("Pearson correlation coefficient:", pearson_corr)
# Print p-value with 10 decimal places
#print("P-value:", "{:.10f}".format(p_value))

# %%
# Regression analysis for MDA 2022 and GEMS exchange 2023 data.
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error
from scipy.stats import pearsonr 

# Define the locations and corresponding dataframes for 2023
locations = [
    ("Becker23", df_BeckerMDA_2023, corn_GEMS_Becker2023_gdd),
    ("Clarissa23", df_ClarissaMDA_2023, corn_GEMS_Clarissa2023_gdd),
    ("Hubbard23", df_HubbardMDA_2023, corn_GEMS_Hubbard2023_gdd),
    ("Dakota23", df_HastingsMDA_2023, corn_GEMS_Hastings2023_gdd),
    ("LittleFalls23", df_LittleFallsMDA_2023, corn_GEMS_LittleFalls2023_gdd),
    ("Ottertail23", df_OtterTailMDA_2023, corn_GEMS_OtterTail2023_gdd),
    ("ParkersPrairie23", df_ParkersPrairieMDA_2023, corn_GEMS_ParkersPrairie2023_gdd),
    ("Perham23", df_PerhamMDA_2023, corn_GEMS_Perham2023_gdd),
    ("PinePoint23", df_PinePointMDA_2023, corn_GEMS_PinePoint2023_gdd),
    ("Rice23", df_RiceMDA_2023, corn_GEMS_Rice2023_gdd),
    ("Staples23", df_StaplesMDA_2023, corn_GEMS_Staples2023_gdd),
    ("Wadena23", df_WadenaMDA_2023, corn_GEMS_Wadena2023_gdd),
    ("Westport23", df_WestportMDA_2023, corn_GEMS_Westport2023_gdd)
]

# Combine all data for regression analysis for 2023
all_data = pd.DataFrame()

for location_name, df_MDA, df_GEMS in locations:
    combined = pd.DataFrame({
        'MDA': df_MDA['CornGDD_daily'], 
        'GEMS': df_GEMS['GDD']
    })
    all_data = pd.concat([all_data, combined])

# Drop any rows with NaN values to ensure consistent lengths
all_data.dropna(inplace=True)

# Extract X and y for regression
X = all_data['MDA'].values.reshape(-1, 1)
y = all_data['GEMS'].values

# Linear regression
model = LinearRegression()
model.fit(X, y)
predictions = model.predict(X)

# Calculate overall metrics
r2 = r2_score(y, predictions)
rmse = np.sqrt(mean_squared_error(y, predictions))
mae = mean_absolute_error(y, predictions)

# Plot
plt.figure(figsize=(10, 6))
plt.scatter(X, y, color='gray', label='Data points')
plt.plot(X, predictions, color='red', label='Regression Line')
plt.plot(X, X, linestyle='--', color='black', label='1:1 Line')  # 1:1 Line
plt.title('Combined Regression Analysis for All Locations for 2023')
plt.xlabel('MDA GDD')
plt.ylabel('GEMS GDD')

plt.legend(loc='upper left')  # Move the legend to top left

# Display R2, RMSE, and MAE
textstr = f'R-squared: {r2:.5f}\nRMSE: {rmse:.5f}°F\nMAE: {mae:.5f}°F'
plt.text(0.95, 0.05, textstr, transform=plt.gca().transAxes, fontsize=12,
          verticalalignment='bottom', horizontalalignment='right')

plt.tight_layout()
plt.show()

# Calculate Pearson correlation coefficient and p-value
pearson_corr, p_value = pearsonr(X.flatten(), y)
# Print Pearson correlation coefficient and p-value
#print("Pearson correlation coefficient:", pearson_corr)
# Print p-value with 10 decimal places
#print("P-value:", "{:.10f}".format(p_value))
